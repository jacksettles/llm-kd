# %%
from tokenizers import ByteLevelBPETokenizer
import re
import glob
import chardet
import nltk
from nltk import Tree
nltk.download('punkt')
import os
from sklearn.model_selection import train_test_split
from collections import Counter
import spacy
import benepar
benepar.download('benepar_en3')
from benepar.spacy_plugin import BeneparComponent
# Out:
# [nltk_data] Downloading package punkt to /home/jts75596/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package benepar_en3 to
# [nltk_data]     /home/jts75596/nltk_data...
# [nltk_data]   Package benepar_en3 is already up-to-date!

# %%
nlp = spacy.load("en_core_web_sm")
nlp.add_pipe("benepar", config={"model": "benepar_en3"})

# Parse a sentence
doc = nlp("A:\tSo, What kind of experience do you, do you have, then with child care?\n")
# Out:
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.

# %%
for sent in doc.sents:
    print(sent._.parse_string)
    print()
# Out:
# (NP (LS A) (: :) (. 	))
#
# (SBARQ (ADVP (RB So)) (, ,) (WHNP (WHNP (WDT What) (NN kind)) (PP (IN of) (NP (NN experience)))) (SQ (VBP do) (NP (PRP you)) (, ,) (SQ (VBP do) (NP (PRP you)) (VP (VBP have))) (, ,) (ADVP (RB then)) (PP (IN with) (NP (NN child) (NN care)))) (. ?) (.
# ))

# %%
pattern = "../../train_100M/processed/*.txt"
files = glob.glob(pattern, recursive=True)

# %%
for file in files:
    file_name = file.split('/')
    corpus_name = file_name[-1]
#     if file == '../../train_100M/processed/childes_raw.txt':
#         continue
    with open(file, 'r') as f:
        content = f.readlines()
    
    outfile = f'../babylm_data/parsed_{corpus_name}'
    with open(outfile, 'w') as output:
        for line in content:
            parsed = nlp(line)
            for sent in parsed.sents:
                parse = sent._.parse_string
                output.write(parse + '\n')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [21], line 12
#      10 with open(outfile, 'w') as output:
#      11     for line in content:
# ---> 12         parsed = nlp(line)
#      13         for sent in parsed.sents:
#      14             output.write(sent._.parse_string + '\n')
#
# File ~/.local/lib/python3.10/site-packages/spacy/language.py:1049, in Language.__call__(self, text, disable, component_cfg)
#    1047     error_handler = proc.get_error_handler()
#    1048 try:
# -> 1049     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1050 except KeyError as e:
#    1051     # This typically happens if a component is not initialized
#    1052     raise ValueError(Errors.E109.format(name=name)) from e
#
# File ~/.local/lib/python3.10/site-packages/benepar/integrations/spacy_plugin.py:151, in BeneparComponent.__call__(self, doc)
#     147 constituent_data = PartialConstituentData()
#     148 wrapped_sents = [SentenceWrapper(sent) for sent in doc.sents]
#     149 for sent, parse in zip(
#     150     doc.sents,
# --> 151     self._parser.parse(
#     152         wrapped_sents,
#     153         return_compressed=True,
#     154         subbatch_max_tokens=self.subbatch_max_tokens,
#     155     ),
#     156 ):
#     157     constituent_data.starts.append(parse.starts + sent.start)
#     158     constituent_data.ends.append(parse.ends + sent.start)
#
# File ~/.local/lib/python3.10/site-packages/benepar/parse_chart.py:416, in ChartParser.parse(self, examples, return_compressed, return_scores, subbatch_max_tokens)
#     414 encoded = [self.encode(example) for example in examples]
#     415 if subbatch_max_tokens is not None:
# --> 416     res = subbatching.map(
#     417         self._parse_encoded,
#     418         examples,
#     419         encoded,
#     420         costs=self._get_lens(encoded),
#     421         max_cost=subbatch_max_tokens,
#     422         return_compressed=return_compressed,
#     423         return_scores=return_scores,
#     424     )
#     425 else:
#     426     res = self._parse_encoded(
#     427         examples,
#     428         encoded,
#     429         return_compressed=return_compressed,
#     430         return_scores=return_scores,
#     431     )
#
# File ~/.local/lib/python3.10/site-packages/benepar/subbatching.py:60, in map(func, costs, max_cost, *data, **common_kwargs)
#      58 for item_ids, *subbatch_items in split(*data, costs=costs, max_cost=max_cost):
#      59     subbatch_out = func(*subbatch_items, **common_kwargs)
# ---> 60     for item_id, item_out in zip(item_ids, subbatch_out):
#      61         res[item_id] = item_out
#      62 return res
#
# File ~/.local/lib/python3.10/site-packages/benepar/parse_chart.py:366, in ChartParser._parse_encoded(self, examples, encoded, return_compressed, return_scores)
#     364 with torch.no_grad():
#     365     batch = self.pad_encoded(encoded)
# --> 366     span_scores, tag_scores = self.forward(batch)
#     367     if return_scores:
#     368         span_scores_np = span_scores.cpu().numpy()
#
# File ~/.local/lib/python3.10/site-packages/benepar/parse_chart.py:284, in ChartParser.forward(self, batch)
#     277     extra_kwargs["decoder_input_ids"] = batch["decoder_input_ids"].to(
#     278         self.device
#     279     )
#     280     extra_kwargs["decoder_attention_mask"] = batch[
#     281         "decoder_attention_mask"
#     282     ].to(self.device)
# --> 284 pretrained_out = self.pretrained_model(
#     285     input_ids, attention_mask=pretrained_attention_mask, **extra_kwargs
#     286 )
#     287 features = pretrained_out.last_hidden_state.to(self.output_device)
#     288 features = features[
#     289     torch.arange(features.shape[0])[:, None],
#     290     # Note that words_from_tokens uses index -100 for invalid positions
#     291     F.relu(words_from_tokens),
#     292 ]
#
# File /apps/eb/PyTorch/1.12.1-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /apps/eb/Transformers/4.34.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:1526, in T5Model.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1523         decoder_attention_mask = decoder_attention_mask.to(self.decoder.first_device)
#    1525 # Decode
# -> 1526 decoder_outputs = self.decoder(
#    1527     input_ids=decoder_input_ids,
#    1528     attention_mask=decoder_attention_mask,
#    1529     inputs_embeds=decoder_inputs_embeds,
#    1530     past_key_values=past_key_values,
#    1531     encoder_hidden_states=hidden_states,
#    1532     encoder_attention_mask=attention_mask,
#    1533     head_mask=decoder_head_mask,
#    1534     cross_attn_head_mask=cross_attn_head_mask,
#    1535     use_cache=use_cache,
#    1536     output_attentions=output_attentions,
#    1537     output_hidden_states=output_hidden_states,
#    1538     return_dict=return_dict,
#    1539 )
#    1541 if not return_dict:
#    1542     return decoder_outputs + encoder_outputs
#
# File /apps/eb/PyTorch/1.12.1-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /apps/eb/Transformers/4.34.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:1123, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1110     layer_outputs = checkpoint(
#    1111         create_custom_forward(layer_module),
#    1112         hidden_states,
#    (...)
#    1120         None,  # past_key_value is always None with gradient checkpointing
#    1121     )
#    1122 else:
# -> 1123     layer_outputs = layer_module(
#    1124         hidden_states,
#    1125         attention_mask=extended_attention_mask,
#    1126         position_bias=position_bias,
#    1127         encoder_hidden_states=encoder_hidden_states,
#    1128         encoder_attention_mask=encoder_extended_attention_mask,
#    1129         encoder_decoder_position_bias=encoder_decoder_position_bias,
#    1130         layer_head_mask=layer_head_mask,
#    1131         cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1132         past_key_value=past_key_value,
#    1133         use_cache=use_cache,
#    1134         output_attentions=output_attentions,
#    1135     )
#    1137 # layer_outputs is a tuple with:
#    1138 # hidden-states, key-value-states, (self-attention position bias), (self-attention weights), (cross-attention position bias), (cross-attention weights)
#    1139 if use_cache is False:
#
# File /apps/eb/PyTorch/1.12.1-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /apps/eb/Transformers/4.34.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:725, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     722 else:
#     723     query_length = None
# --> 725 cross_attention_outputs = self.layer[1](
#     726     hidden_states,
#     727     key_value_states=encoder_hidden_states,
#     728     attention_mask=encoder_attention_mask,
#     729     position_bias=encoder_decoder_position_bias,
#     730     layer_head_mask=cross_attn_layer_head_mask,
#     731     past_key_value=cross_attn_past_key_value,
#     732     query_length=query_length,
#     733     use_cache=use_cache,
#     734     output_attentions=output_attentions,
#     735 )
#     736 hidden_states = cross_attention_outputs[0]
#     738 # clamp inf values to enable fp16 training
#
# File /apps/eb/PyTorch/1.12.1-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /apps/eb/Transformers/4.34.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:636, in T5LayerCrossAttention.forward(self, hidden_states, key_value_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, query_length, output_attentions)
#     623 def forward(
#     624     self,
#     625     hidden_states,
#    (...)
#     633     output_attentions=False,
#     634 ):
#     635     normed_hidden_states = self.layer_norm(hidden_states)
# --> 636     attention_output = self.EncDecAttention(
#     637         normed_hidden_states,
#     638         mask=attention_mask,
#     639         key_value_states=key_value_states,
#     640         position_bias=position_bias,
#     641         layer_head_mask=layer_head_mask,
#     642         past_key_value=past_key_value,
#     643         use_cache=use_cache,
#     644         query_length=query_length,
#     645         output_attentions=output_attentions,
#     646     )
#     647     layer_output = hidden_states + self.dropout(attention_output[0])
#     648     outputs = (layer_output,) + attention_output[1:]  # add attentions if we output them
#
# File /apps/eb/PyTorch/1.12.1-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /apps/eb/Transformers/4.34.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:527, in T5Attention.forward(self, hidden_states, mask, key_value_states, position_bias, past_key_value, layer_head_mask, query_length, use_cache, output_attentions)
#     523 # get key/value states
#     524 key_states = project(
#     525     hidden_states, self.k, key_value_states, past_key_value[0] if past_key_value is not None else None
#     526 )
# --> 527 value_states = project(
#     528     hidden_states, self.v, key_value_states, past_key_value[1] if past_key_value is not None else None
#     529 )
#     531 # compute scores
#     532 scores = torch.matmul(
#     533     query_states, key_states.transpose(3, 2)
#     534 )  # equivalent of torch.einsum("bnqd,bnkd->bnqk", query_states, key_states), compatible with onnx op>9
#
# File /apps/eb/Transformers/4.34.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:502, in T5Attention.forward.<locals>.project(hidden_states, proj_layer, key_value_states, past_key_value)
#     498     hidden_states = shape(proj_layer(hidden_states))
#     499 elif past_key_value is None:
#     500     # cross-attn
#     501     # (batch_size, n_heads, seq_length, dim_per_head)
# --> 502     hidden_states = shape(proj_layer(key_value_states))
#     504 if past_key_value is not None:
#     505     if key_value_states is None:
#     506         # self-attn
#     507         # (batch_size, n_heads, key_length, dim_per_head)
#
# File /apps/eb/Transformers/4.34.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:487, in T5Attention.forward.<locals>.shape(states)
#     485 def shape(states):
#     486     """projection"""
# --> 487     return states.view(batch_size, -1, self.n_heads, self.key_value_proj_dim).transpose(1, 2)
#
# KeyboardInterrupt:
